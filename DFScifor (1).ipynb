# %%
import pandas as pd

# %% [markdown]
# crt a df obj from list containing two list in which one list contains the target and the other list contains the sales of any 5 departments

# %%
data = [[10000,20000,30000,40000,45000], [9000,18000,23000,35000,44000]]
df = pd.DataFrame(data, columns = ['food', 'cosmetics', 'raw materials', 'textiles', 'electronics'], index = ['Target', 'Sales'])
df
# Out:
#          food  cosmetics  raw materials  textiles  electronics
# Target  10000      20000          30000     40000        45000
# Sales    9000      18000          23000     35000        44000

# %% [markdown]
# crt a df obj from the list containing the dict having name, age and marks of students of 5 different section

# %%
data = [
    {'Name': 'Mariya', 'Age': 18, 'Marks': 85, 'Section': 'A'},
    {'Name': 'Maneesha', 'Age': 17, 'Marks': 92, 'Section': 'B'},
    {'Name': 'Aswathy', 'Age': 19, 'Marks': 78, 'Section': 'C'},
    {'Name': 'Ammu', 'Age': 18, 'Marks': 89, 'Section': 'D'},
    {'Name': 'Achu', 'Age': 17, 'Marks': 95, 'Section': 'E'}
]
df = pd.DataFrame(data)
df
# Out:
#        Name  Age  Marks Section
# 0    Mariya   18     85       A
# 1  Maneesha   17     92       B
# 2   Aswathy   19     78       C
# 3      Ammu   18     89       D
# 4      Achu   17     95       E

# %% [markdown]
# crt a df obj from dict containing marks of 4 subjects for sumith and rohith for the year 2022

# %%
data = {
    'Name': ['Sumith', 'Rohith'],
    'Year': [2022, 2022],
    'Maths': [85, 78],
    'DBMS': [92, 89],
    'ML': [75, 80],
    'CN': [88, 90]
}
df = pd.DataFrame(data)
df
# Out:
#      Name  Year  Maths  DBMS  ML  CN
# 0  Sumith  2022     85    92  75  88
# 1  Rohith  2022     78    89  80  90

# %% [markdown]
# crt a df from the series obj as staff and their salaries for the month of september 2023 in the 3 departments often IT company

# %%
staff = pd.Series(['Mariya', 'Maneesha', 'Aswathy', 'Ammu', 'Achu'])
salaries = pd.Series([18000, 17000, 19000, 18000, 17000])
dep = pd.Series(['HR', 'IT', 'Sales', 'HR', 'Sales'])
df = pd.DataFrame({'Name': staff, 'Salary': salaries, 'Department': dep})
df
# Out:
#        Name  Salary Department
# 0    Mariya   18000         HR
# 1  Maneesha   17000         IT
# 2   Aswathy   19000      Sales
# 3      Ammu   18000         HR
# 4      Achu   17000      Sales
