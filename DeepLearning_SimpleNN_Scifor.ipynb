# %% [markdown]
# # Deep Learning using Keras

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
len(x_test)
# Out:
# 10000

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
plt.matshow(x_train[1])

# %%
y_train.reshape(-1,)
y_train[2]

# %%
from tensorflow.keras import layers, models
model = models.Sequential()
model.add(layers.Dense(10, input_shape = (784,), activation='sigmoid'))

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x_train_flat, y_train, epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4675 - accuracy: 0.8781
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3036 - accuracy: 0.9141
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2830 - accuracy: 0.9214
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2729 - accuracy: 0.9246
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2666 - accuracy: 0.9255
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2620 - accuracy: 0.9268
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2583 - accuracy: 0.9280
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2553 - accuracy: 0.9295
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2533 - accuracy: 0.9297
# Epoch 10/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2513 - accuracy: 0.9301

# %%
model.evaluate(x_test_flat, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2662 - accuracy: 0.9278
# [0.2662431001663208, 0.9277999997138977]

# %%
y_pred = model.predict(x_test_flat)
y_pred[5]
# Out:
# 313/313 [==============================] - 1s 1ms/step
# array([2.0704258e-05, 9.9876380e-01, 6.3626945e-01, 3.9129373e-01,
#        4.3140859e-03, 1.7235007e-02, 6.6127740e-03, 6.3021886e-01,
#        5.6131500e-01, 1.5521508e-01], dtype=float32)

# %%
y_pred_lab = [np.argmax(i) for i in y_pred]
y_pred_lab[:5]
# Out:
# [7, 2, 1, 0, 4]

# %%
y_test[:5]
# Out:
# array([7, 2, 1, 0, 4], dtype=uint8)

# %%
con_mat = tf.math.confusion_matrix(labels = y_test, predictions = y_pred_lab)
con_mat
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 952,    0,    2,    2,    1,    7,   12,    2,    2,    0],
#        [   0, 1115,    4,    2,    0,    1,    3,    2,    8,    0],
#        [   3,    8,  938,    7,    7,    5,   11,    8,   42,    3],
#        [   1,    0,   26,  903,    1,   31,    2,    9,   31,    6],
#        [   1,    1,    8,    1,  912,    0,   10,    4,   12,   33],
#        [   7,    3,    2,   22,   10,  784,   15,    7,   37,    5],
#        [   7,    3,    9,    1,    7,   12,  913,    2,    4,    0],
#        [   1,    6,   28,    4,    8,    1,    0,  943,    5,   32],
#        [   4,    7,    6,   12,    8,   16,    8,    7,  899,    7],
#        [   7,    8,    3,    6,   27,    6,    0,   21,   12,  919]],
#       dtype=int32)>

# %%
plt.figure(figsize = (16, 8))
sns.heatmap(con_mat, annot = True, fmt = 'd')
plt.xlabel("pred values")
plt.ylabel("actual_values")
# Out:
# Text(170.72222222222223, 0.5, 'actual_values')

# %%
from tensorflow.keras import layers, models
model = models.Sequential()
model.add(layers.Dense(64, input_shape = (784,), activation='relu'))
model.add(layers.Dense(10, activation = 'sigmoid'))

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x_train_flat, y_train, epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2989 - accuracy: 0.9152
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1492 - accuracy: 0.9568
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1095 - accuracy: 0.9676
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0877 - accuracy: 0.9735
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0726 - accuracy: 0.9779
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0609 - accuracy: 0.9815
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0515 - accuracy: 0.9841
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0442 - accuracy: 0.9862
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0389 - accuracy: 0.9880
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0325 - accuracy: 0.9901

# %%
model.evaluate(x_test_flat, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0925 - accuracy: 0.9744
# [0.09247500449419022, 0.974399983882904]

# %%
y_pred = model.predict(x_test_flat)
y_pred[5]
# Out:
# 313/313 [==============================] - 1s 2ms/step
# array([8.14665618e-05, 9.99780893e-01, 3.94629809e-04, 1.59311399e-03,
#        3.68562117e-02, 4.55829795e-05, 3.30492214e-04, 7.44845271e-01,
#        1.16033144e-01, 8.26742128e-03], dtype=float32)

# %%
con_mat = tf.math.confusion_matrix(labels = y_test, predictions = y_pred_lab)
con_mat
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 952,    0,    2,    2,    1,    7,   12,    2,    2,    0],
#        [   0, 1115,    4,    2,    0,    1,    3,    2,    8,    0],
#        [   3,    8,  938,    7,    7,    5,   11,    8,   42,    3],
#        [   1,    0,   26,  903,    1,   31,    2,    9,   31,    6],
#        [   1,    1,    8,    1,  912,    0,   10,    4,   12,   33],
#        [   7,    3,    2,   22,   10,  784,   15,    7,   37,    5],
#        [   7,    3,    9,    1,    7,   12,  913,    2,    4,    0],
#        [   1,    6,   28,    4,    8,    1,    0,  943,    5,   32],
#        [   4,    7,    6,   12,    8,   16,    8,    7,  899,    7],
#        [   7,    8,    3,    6,   27,    6,    0,   21,   12,  919]],
#       dtype=int32)>

# %%
plt.figure(figsize = (16, 8))
sns.heatmap(con_mat, annot = True, fmt = 'd')
plt.xlabel("pred values")
plt.ylabel("actual_values")
# Out:
# Text(170.72222222222223, 0.5, 'actual_values')
